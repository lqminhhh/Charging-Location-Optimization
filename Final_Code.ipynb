# %% [markdown]
# # Final Project - DA 353
#
# ## Dr. Bonifonte
# ## Minh Le & Yen Nguyen

# %% [markdown]
# ### I. Background and Introduction
#
# The adoption of electric vehicles (EVs) is increasing worldwide, mainly driven by growing awareness of environmental issues and technological advancements. These types of vehicles are now favored and recognized by the majority of consumers. With the increasing number of new energy electric vehicles, the demand for charging stations for these vehicles is also increasing. This makes the strategic placement of charging stations crucial, helping the government optimize infrastructure efficiency by minimizing the need for excessive stations. Finding the right locations for these stations is therefore important, ensuring they can provide convenient access for all EV users, while contributing to a more sustainable future of transportation.
#
# For this project, we aim to optimize the allocation of electric vehicles charging stations locations that effectively minimize the number of stations. We chose Washington state for our optimization model. Since the current data is too large, we plan to focus on the metropolitan area in Washington state, such as Seattle, to reduce the complexity of the problem. Based on the given dataset provided by data.gov about the registered electric vehicles, we are hoping to effectively design and build strategic placements of stations that can cover all the locations and meet the demand of those registered cars.
#
#
# ### II. Data Preprocessing & Exploration
# Now, we will select all the data we need for our optimization problem. We will only focus on the biggest city in Washington State, which is Seattle.

# %%
# import packages
import numpy as np
import pandas as pd
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
import geopy.distance
import folium
from itertools import combinations, permutations, product
from math import sqrt
import plotly.graph_objs as go

# %%
# load datset and select needed columns
df = pd.read_csv("./Electric_Vehicle_Population_Data.csv")
df = df[["VIN (1-10)", "County", "City", "Postal Code", "Vehicle Location"]]
df.set_index("VIN (1-10)", inplace=True)

# %%
# select data that are from Seattle
df_seattle = df.loc[df["City"] == "Seattle"]
df_seattle.head()
# Out:
#            County     City  Postal Code              Vehicle Location
# VIN (1-10)
# 5YJYGDEE1L   King  Seattle      98122.0  POINT (-122.30839 47.610365)
# 5YJSA1E4XK   King  Seattle      98109.0  POINT (-122.34848 47.632405)
# 5YJYGDEEXL   King  Seattle      98144.0  POINT (-122.30823 47.581975)
# 1N4AZ0CP0F   King  Seattle      98119.0  POINT (-122.363815 47.63046)
# 1N4AZ0CP6D   King  Seattle      98107.0   POINT (-122.37815 47.66866)

# %% [markdown]
# First, we want to explore the locations of all the registered vehicles. We will use `Postal Code` to identify where the EVs are registered in Seattle.

# %%
# select unique postal code in the dataset
unique_postal_codes = df_seattle['Postal Code'].unique()

# how many vehicles are there for each postal code?
postal_code_counts = df_seattle.groupby('Postal Code').size().reset_index(name='Count')

# Create a grid representation using postal codes
grid = {}

# Populate grid with coordinates
for index, row in df_seattle.iterrows():
    code = row['Postal Code']
    log = row["Vehicle Location"].split(" ")[1][1:]
    lat = row["Vehicle Location"].split(" ")[2][:-1]
    grid[code] = (float(lat), float(log))

# %% [markdown]
# We will now create a map to see the location of each `Postal Code`:

# %%
#Plot the map for model 1
map_mod_1 = folium.Map(location=[47.6062, -122.3321], zoom_start=10.45)
for key, value in grid.items():
    folium.Marker(location=value,
                    popup=key,
                    icon=folium.Icon(icon = "car",
                                     color='blue', prefix='fa')).add_to(map_mod_1)
        
map_mod_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# For further development and analysis, we will convert the location of our `Postal Code` to a grid location.

# %%
# Define maximum and minimum longitude and latitude ranges
min_lon, max_lon = -122.45, -122.25  
min_lat, max_lat = 47.55, 47.75  

# Define grid size
grid_size = 10

# Function to map longitude and latitude to grid location
def map_to_grid(lon, lat):
    lon_idx = (lon - min_lon) / (max_lon - min_lon) * grid_size
    lat_idx = (lat - min_lat) / (max_lat - min_lat) * grid_size
    return lon_idx, lat_idx

# Convert coordinates to grid locations
grid_locations = {zipcode: map_to_grid(lon, lat) for zipcode, (lat, lon) in grid.items()}

# Plot grid locations
plt.figure(figsize=(10, 8))
for zipcode, (lon_idx, lat_idx) in grid_locations.items():
    plt.plot(lon_idx, lat_idx, 'b*', markersize = 10)
    plt.text(lon_idx, lat_idx, str(int(zipcode)), fontsize=7)

plt.title('Zip Codes Grid Locations')
plt.xlabel('Longitude Grid')
plt.ylabel('Latitude Grid')
plt.legend(['Zip Code Locations'])
plt.grid(True)
plt.show()

# %%
# Grid locations converted from the given longitudes and latitudes of postal codes
df = pd.DataFrame.from_dict(grid_locations, orient='index', columns=["Longitude", "Latitude"])

# Compute the maximum and minimum longitude and latitude converted grid locations
max_longitude = df["Longitude"].max()
min_longitude = df["Longitude"].min()
max_latitude = df["Latitude"].max()
min_latitude = df["Latitude"].min()

print("Maximum Longitude:", max_longitude)
print("Minimum Longitude:", min_longitude)
print("Maximum Latitude:", max_latitude)
print("Minimum Latitude:", min_latitude)
# Out:
# Maximum Longitude: 12.649999999999826
# Minimum Longitude: 2.7907500000004464
# Maximum Latitude: 11.13950000000001
# Minimum Latitude: -5.763499999999684

# %% [markdown]
# Based on the grid location, we established the range within which candidate locations should be selected: longitude [3, 13] and latitude [-6, 12] with a step size of 0.5.

# %%
# Select candidate grid locations within the specified range
candidate_grid_locations = {idx: (i, j) for idx, (i, j) in enumerate([(i, j) for i in np.round(np.arange(2, 13.2, 0.5), 10) for j in np.round(np.arange(-6, 12.2, 0.5), 10)])}

# Plot grid locations
plt.figure(figsize=(10, 8))

# Plot candidate locations (red points)
for candidate, (lon_idx, lat_idx) in candidate_grid_locations.items():
    plt.plot(lon_idx, lat_idx, 'rs', markersize = 4)

for zipcode, (lon_idx, lat_idx) in grid_locations.items():
    plt.plot(lon_idx, lat_idx, 'b*', markersize = 10)
    plt.text(lon_idx, lat_idx, str(int(zipcode)), fontsize=7)

plt.title('Zip Codes Grid Locations with Candidate Locations')
plt.xlabel('Longitude Grid')
plt.ylabel('Latitude Grid')
handles = [plt.Line2D([], [], marker='*', color='blue', linestyle='None', markersize=10),
           plt.Line2D([], [], marker='s', color='red', linestyle='None', markersize=8)]
labels = ['Zip Code Locations', 'Candidate Locations']
plt.legend(handles, labels)
plt.grid(True)
plt.show()

# %% [markdown]
# **Remove invalid stations**
#
# We define a `grid_to_map` function which converts the grid locations to real locations. By plotting in real mapping, we see that there are many invalid stations placed in the water that we need to remove from our model. We first systematically define three water areas (`remove_area1`, `remove_area2`, and `remove_area3`) in King County, where we expect the majority of grid points to be situated in bodies of water. However, within these areas, we've identified specific grid locations (`keep_location1`, `keep_location2`, `keep_location3`) known to be on land, such as those under bridges or in built-up areas, which we've retained despite being within the defined removal areas.
#
# Additionally, we've compiled a list of central water locations (`remove_location`), such as those near bridges, which we've excluded from consideration regardless of their surrounding area. This dual approach ensures that our candidate station locations are predominantly situated on land, balancing automated removal with manual verification to accurately capture land-based locations within King County.
#
# Given the complexity of the computation steps involved in determining the stations to be removed and retained, we've omitted them for brevity, providing only the final outcomes after thorough area identification.

# %%
# Define the grid locations we want to remove
locations_to_remove = {(i, j) for i in np.round(np.arange(10, 13.1, 0.5), 10) for j in np.round(np.arange(0, 12.1, 0.5), 10)}

# Remove the specified grid locations from candidate_grid_locations
candidate_grid_locations = {idx: (i, j) for idx, (i, j) in candidate_grid_locations.items() if (i, j) not in locations_to_remove}

# Define the grid locations you want to remove
remove_area1 = {(i, j) for i in np.round(np.arange(2,3.6, 0.5), 10) for j in np.round(np.arange(-6, 12.1, 0.5), 10)}
remove_area2 = {(i, j) for i in np.round(np.arange(8.5,9.6, 0.5), 10) for j in np.round(np.arange(0.5, 10.1, 0.5), 10)}
remove_area3 = {(i, j) for i in np.round(np.arange(9.5,12.1, 0.5), 10) for j in np.round(np.arange(-2.0, -0.4, 0.5), 10)}
keep_location1 = [14, 21, 22, 23, 24, 47, 50, 51, 52, 58, 59, 60, 61, 62, 63, 82, 83, 84, 85, 86, 87, 88, 89, 
                 90, 95, 96, 97, 98, 99, 100, 101, 108, 109, 110, 118, 119, 120, 121, 122, 126, 131, 132, 
                 133, 135, 136, 137, 138, 139, 143, 144, 145, 146, 147]
keep_location2 = [513, 510, 509, 508, 507, 506, 505, 504, 502, 501, 500, 495, 494, 530, 531, 541, 542, 543, 544, 586, 585, 580, 579, 567]
keep_location3 = [563, 600, 637, 564, 749, 786, 676, 713, 751, 714, 677, 640]
remove_location = [148, 149, 151, 152, 153, 154, 164, 165, 166, 167, 185, 186, 200, 201, 202, 203, 331, 284, 321, 318, 317, 316, 279, 280, 240, 239, 238, 276, 235, 271, 466, 788]

# Remove the specified grid locations from candidate_grid_locations
candidate_grid_locations = {idx: (i, j) for idx, (i, j) in candidate_grid_locations.items() if (i, j) not in remove_area1 or idx in keep_location1}
candidate_grid_locations = {idx: (i, j) for idx, (i, j) in candidate_grid_locations.items() if (i, j) not in remove_area2 or idx in keep_location2}
candidate_grid_locations = {idx: (i, j) for idx, (i, j) in candidate_grid_locations.items() if (i, j) not in remove_area3 or idx in keep_location3}
candidate_grid_locations = {idx: (i, j) for idx, (i, j) in candidate_grid_locations.items() if idx not in remove_location}

# Plot grid locations
plt.figure(figsize=(10, 8))

# Plot candidate locations (red points)
for candidate, (lon_idx, lat_idx) in candidate_grid_locations.items():
    plt.plot(lon_idx, lat_idx, 'rs', markersize = 4)

for zipcode, (lon_idx, lat_idx) in grid_locations.items():
    plt.plot(lon_idx, lat_idx, 'b*', markersize = 10)
    plt.text(lon_idx, lat_idx, str(int(zipcode)), fontsize=7)

plt.title('Zip Codes Grid Locations with Candidate Locations')
plt.xlabel('Longitude Grid')
plt.ylabel('Latitude Grid')
handles = [plt.Line2D([], [], marker='*', color='blue', linestyle='None', markersize=10),
           plt.Line2D([], [], marker='s', color='red', linestyle='None', markersize=8)]
labels = ['Zip Code Locations', 'Candidate Locations']
plt.legend(handles, labels)
plt.grid(True)
plt.show()

# %% [markdown]
# ### III. Model Formulation
#
# To streamline our project, we make the following assumptions:
# - We assume uniform power consumption demand for each vehicle, approximating it based on the average power consumption of electric cars.
# - We consider the construction cost as well as the power capacity of a new station to be consistent across all locations and irrespective of demand variations.
# - We assume the location of each vehicles is specified by `Postal Code`.
# - Each charger can supply a car.
#
# We want to develop a linear programming model to solve the problem. The structure of the model is:
#
# 1. <b> Set: </b>
#     - Let $Z$ represent the set of postal codes obtained from the dataset.
#     - Let $S$ denote the set of candidate charging locations.
# 2. <b> Data: </b>
#     - $D$: the maximum certain distance threshold between the charging location and the vehicle.
#     - $ST$: the maximum stations can be installed.
#     - $C_{min}$ and $C_{max}$: the minimum and maximum number of chargers we can have at a charging station $j$.
#     - $d_{ij}$: the distance between vehicle in postal code $i$ ($i \in Z$) and station $j$ ($j \in S$).
#     - $n_i$: the number of cars require charging in postal code $i$.
#
# 3. <b> Decision Variables: </b>
#     - $C_{j}$: Binary variable indicating whether to open the charging station $j$, $j \in S$.
#     - $X_{ij}$: Continuous variable representing the proportion of vehicles in postal code $i$ ($i \in Z$) chooses station $j$ ($j \in S$) for charging service.
#     - $N_{j}$: The number of chargers installed at the charging station $j$, $j \in S$
#
# 4. <b> Objective Function: </b> Maximize the station coverage of the stations opened:
# \begin{equation*}
# \max \displaystyle\sum_{i \in Z} n_i X_{ij}
# \end{equation*}
#
# 5. <b> Constraints: </b>
#     - Only charge at the stations that have been selected: $ X_{ij} \leq C_{j} \quad \forall i\in Z, j\in S$.
#     - The total coverage percentage of each postal must not exceed 1: $\displaystyle \sum_{j\in S} X_{ij} \leq 1 \quad \forall i\in Z$.
#     - Limit the distance between each postal code and its assigned charging station to a maximum threshold of D units:
#     $d_{ij} C_j \leq D \quad \forall i \in Z, j \in S$.
#     - Ensure that the total demand supplied by each charging station equals to the total supply of each station:
#     $\displaystyle \sum_{i \in Z} n_i X_{ij} =  N_j \quad \forall j\in S$.
#     - The number of chargers installed at each chosen station must meet the required minimum and maximum threshold: $C_{\text{min}} C_j \leq N_j \leq C_{\text{max}} C_j \quad \forall j\in S$
#     - Ensure that only a limited number of stations are opened: $\displaystyle \sum_{j \in S} C_j \leq ST$.

# %% [markdown]
# ### IV. Model Implementation

# %%
# Function to create the Euclidean distances between the charging locations and the vehicles in zip code i
def distance(loc1, loc2):
    dx = loc1[0] - loc2[0]
    dy = loc1[1] - loc2[1]
    return sqrt(dx*dx + dy*dy)

# List of postal codes and list of candidate indices
codes = grid_locations.keys()
candidate = candidate_grid_locations.keys()

# Generate a list of pairs of postal codes and the candidate indices
cartesian_prod = list(product(codes, candidate))

# Compute the distances between each pair of code and candidate stations
distances = {(c, f): distance(grid_locations[c], candidate_grid_locations[f]) for c, f in cartesian_prod}

# %% [markdown]
# We now set the maximum distance threshold between the charging location and the vehicle to be within 2.0 unit in grid locations.
#
# In our grid system, the longitude ranges from -6 to 13 and the latitude ranges from -6 to 12. To determine the real-life size of each grid cell, we calculate the longitude and latitude grid sizes:
# - Longitude grid size: $\frac{{13 - (-6)}}{10} = 1.9$
#
# - Latitude grid size: $\frac{{12 - (-6)}}{10} = 1.8$
#
# This means that each unit in the grid represents approximately 1.9 units in longitude and 1.8 units in latitude in real-life distance.
#
# Assuming each unit in the grid corresponds to 1 mile in both longitude and latitude, 2 units in the grid would cover:
# - Longitude distance: $2 \times 1.9 = 3.8$ miles
# - Latitude distance: $2 \times 1.8 = 3.6$ miles
#
# Therefore, 2 units in the grid would cover approximately 3.8 miles in longitude and 3.6 miles in latitude in real-life distance. Thus, the 2 units distance threshold we choose is equal to $\sqrt{{3.8^2 + 3.6^2}} = 5.23$ miles in real-life. Since these are Euclidean distances, real distances considering road path will be somewhat larger, so we estimate the real-life distance to be around 10-12 miles.

# %%
def maximum_dist_thres(threshold):
    dict = {}
    for c, f in cartesian_prod:
        if distances[(c, f)] <= threshold:
            dict[(c, f)] = distances[(c, f)]
    return dict

threshold = 2.0 # set the threshold to be 2.0
distances_filtered = maximum_dist_thres(threshold)

# restrict the distance to be within a certain threshold and store it into a new set
ck = []
cand = {}
for i, j in distances_filtered.keys():
    ck.append((i, j))
    cand[j] = candidate_grid_locations[j]

# %% [markdown]
# Then, we will solve the model using Gurobi using the set of candidate locations that driver will choose within the tolerable distance. In addition, here are the assumptions we made for model implementation:
# - Maximum chargers of each station: 80 chargers
# - Minimum chargers of each station: 20 chargers
# - Maximum certain distance threshold between the charging location and the vehicle: 2.0 in grid distance(`D = 2.0`)
# - The allowable number of stations to be constructed is 450, mirroring real-world data with around 500 stations.

# %%
# Model 1

model1 = gp.Model("Station Cover")
model1.Params.LogToConsole = 0 # Suppress noisy output

## Data
### Number of cars requires charging at location i
n = postal_code_counts.set_index('Postal Code')['Count'].to_dict()

## Variables: 
### Whether to open charging station j?
C = model1.addVars(cand.keys(), vtype = GRB.BINARY, name = "c")

### The proportion of vehicles in postal code i choose station j for charging service
X_var = model1.addVars(ck, lb = 0.0, ub = 1.0, vtype = GRB.CONTINUOUS, name = "x")

### Number of chargers will be installed in candidate location j
N = model1.addVars(cand.keys(), vtype = GRB.INTEGER, lb = 0, ub = 80,  name = "N")

## Objective
model1.setObjective(gp.quicksum(X_var[i, j] * n[i] for i, j in ck), GRB.MAXIMIZE)

## Constraints
### Vehicle charging constraint
model1.addConstrs(gp.quicksum(X_var[i, j] for j in cand.keys() if (i, j) in ck) <= 1 for i in grid_locations.keys())

### Supply-Demand balance constraint
model1.addConstrs(gp.quicksum(n[i] * X_var[i, j] for i in grid_locations.keys() if (i, j) in ck) == N[j] for j in cand.keys())

### Restrict the number of station to be constructed
model1.addConstr(gp.quicksum(C[j] for j in cand.keys()) <= 450)

### Can be charge only when there is charging location
model1.addConstrs(X_var[i, j] <= C[j] for i, j in ck)

### At least 20 for each chosen location
model1.addConstrs(N[j] >= 20 * C[j] for j in cand.keys())

# optimize model
model1.optimize()

if model1.status == GRB.OPTIMAL:
    print("Optimal Solution:")
    print("Number of vehicles can be covered:", round(model1.ObjVal) , "vehicles")
    print("Cover", round(model1.ObjVal/len(df_seattle)*100,2), "% of the demand")
    result2 = []
    for j in cand.keys():
        if C[j].x > 0.5:
            result2.append(j)
    print("Number of stations installed:", len(result2))
else:
    print("No optimal solution found.")
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-02-06
# Optimal Solution:
# Number of vehicles can be covered: 22236 vehicles
# Cover 75.51 % of the demand
# Number of stations installed: 282

# %%
result_table2 = []
for (i, j) in ck:
    if round(X_var[(i,j)].X, 2) > 0:
        result_table2.append((int(i), j, round(X_var[(i,j)].X, 4)*100, int(n[i] * X_var[(i,j)].X), N[j].X , distances[(i, j)]))

result_table2 = pd.DataFrame(result_table2)
result_table2.columns = ["Postal Code", "Station", "Coverage Percentage", "Number of cars assigned", "Number of chargers", "Distances"]
result_table2 = result_table2.sort_values(by="Station", ascending=True)
a = result_table2.groupby('Station').agg({
    'Number of chargers': 'sum'
}).reset_index()
station_chargers_dict = {row['Station']: row['Number of chargers'] for index, row in a.iterrows()}
result_table2.head(20)
# Out:
#      Postal Code  Station  Coverage Percentage  Number of cars assigned  \
# 494        98116       14                 7.03                       80
# 454        98199       21                 6.47                       80
# 84         98107       22                 3.78                       39
# 455        98199       22                 3.23                       40
# 85         98107       23                 7.55                       80
# 86         98107       24                 7.55                       80
# 495        98116       47                 7.03                       80
# 496        98116       50                 7.03                       80
# 497        98116       51                 7.03                       80
# 498        98116       52                 7.03                       79
# 73         98119       58                 4.30                       40
# 456        98199       58                 3.23                       40
# ...

# %%
# Select the chosen candidate locations after optimizing using Gurobi
chosen_locations = {idx: (i, j) for idx, (i, j) in candidate_grid_locations.items() if idx in result2}

# Plot grid locations
plt.figure(figsize=(10, 8))

# determine the max supply for normalization
max_supply = max(station_chargers_dict.values())
# Plot candidate locations (red points)
for candidate, (lon_idx, lat_idx) in chosen_locations.items():
    size = 5 + 6 * (station_chargers_dict[candidate] / max_supply)
    plt.plot(lon_idx, lat_idx, 'ro', markersize=size, label='Candidate Locations')

# Plot zip code locations (blue stars)
for zipcode, (lon_idx, lat_idx) in grid_locations.items():
    plt.plot(lon_idx, lat_idx, 'b*', markersize=8, label='Zip Code Locations')
    plt.text(lon_idx, lat_idx, n[zipcode], fontsize=7)
    
plt.title('Zip Codes Grid Locations with Chosen Candidate Locations')
plt.xlabel('Longitude Grid')
plt.ylabel('Latitude Grid')
handles = [plt.Line2D([], [], marker='*', color='blue', linestyle='None', markersize=10),
           plt.Line2D([], [], marker='s', color='red', linestyle='None', markersize=8),
           plt.Line2D([], [], linestyle='-', color='blue')]
labels = ['Zip Code Locations', 'Candidate Locations', 'Lines']
plt.legend(handles, labels)
plt.grid(True)
plt.show()

# %% [markdown]
# ### V. Sensitiviy Analysis
#
# We will make a sensitivity test to figure out the key factor that shape our model.

# %%
# List to store the objective values for different supply capacities
coverage_values = []

# Define a range of supply capacities for each station
supply_capacity_range = range(20, 301)  # Capacity power varies from 1 to 1000

# Data
n = postal_code_counts.set_index('Postal Code')['Count'].to_dict()

for supply_capacity in supply_capacity_range:
    # Model creation
    model2 = gp.Model("Station Cover")
    model2.Params.LogToConsole = 0  # Suppress noisy output

    # Variables
    C2 = model2.addVars(cand.keys(), vtype=GRB.BINARY, name="c")
    X_var2 = model2.addVars(ck, lb=0.0, ub=1.0, vtype=GRB.CONTINUOUS, name="x")
    N2 =  model2.addVars(cand.keys(), vtype = GRB.INTEGER, lb = 0, ub = supply_capacity,  name = "N")
    # Objective
    model2.setObjective(gp.quicksum(X_var2[i, j] * n[i] for i, j in ck), GRB.MAXIMIZE)


    model2.addConstrs(gp.quicksum(X_var2[i, j] for j in cand.keys() if (i, j) in ck) <= 1 for i in grid_locations.keys())
    model2.addConstrs(gp.quicksum(n[i] * X_var2[i, j] for i in grid_locations.keys() if (i, j) in ck) == N2[j] for j in cand.keys())
    model2.addConstr(gp.quicksum(C2[j] for j in cand.keys()) <= 450)
    model2.addConstrs(X_var2[i, j] <= C2[j] for i, j in ck)
    model2.addConstrs(N2[j] >= 20 * C2[j] for j in cand.keys())
    # Optimize model
    model2.optimize()

    # Store the objective value
    if model2.status == GRB.OPTIMAL:
        # Compute the percentage of vehicles that the optimal solution can cover
        coverage_values.append(model2.ObjVal/len(df_seattle)*100)
    else:
        coverage_values.append(0)  # If no optimal solution found, store 0

# Plot the sensitivity analysis results
plt.plot(supply_capacity_range, coverage_values)
plt.xlabel('Supply Capacity of Each Station')
plt.ylabel('Percentage of Vehicles Covered')
plt.title('Sensitivity Analysis: Supply Capacity vs. Vehicles Covered')
plt.grid(True)
plt.show()

# %%
# List to store the objective values for different supply capacities
coverage_values = []

# Define a range of maximum distances
threshold_range = np.round(np.arange(1, 15, 0.2), 10)  # Vary from 1 to 15 with a step size of 0.2

# Data
n = postal_code_counts.set_index('Postal Code')['Count'].to_dict()

for threshold in threshold_range:
    distances_filtered = maximum_dist_thres(threshold)

    # restrict the distance to be within a certain threshold and store it into a new set
    ck = []
    cand = {}
    for i, j in distances_filtered.keys():
        ck.append((i, j))
        cand[j] = candidate_grid_locations[j]

    # Model creation
    model3 = gp.Model("Station Cover")
    model3.Params.LogToConsole = 0  # Suppress noisy output

    # Variables
    C3 = model3.addVars(cand.keys(), vtype=GRB.BINARY, name="c")
    X_var3 = model3.addVars(ck, lb=0.0, ub=1.0, vtype=GRB.CONTINUOUS, name="x")
    N3 =  model3.addVars(cand.keys(), vtype = GRB.INTEGER, lb = 0, ub = 80,  name = "N")
    # Objective
    model3.setObjective(gp.quicksum(X_var3[i, j] * n[i] for i, j in ck), GRB.MAXIMIZE)

    # Constraints
    model3.addConstrs(gp.quicksum(X_var3[i, j] for j in cand.keys() if (i, j) in ck) <= 1 for i in grid_locations.keys())
    model3.addConstrs(gp.quicksum(n[i] * X_var3[i, j] for i in grid_locations.keys() if (i, j) in ck) == N3[j] for j in cand.keys())
    model3.addConstr(gp.quicksum(C3[j] for j in cand.keys()) <= 450)
    model3.addConstrs(X_var3[i, j] <= C3[j] for i, j in ck)
    model3.addConstrs(N3[j] >= 20 * C3[j] for j in cand.keys())

    # Optimize model
    model3.optimize()

    # Store the objective value
    if model3.status == GRB.OPTIMAL:
        # Compute the percentage of vehicles that the optimal solution can cover
        coverage_values.append(model3.ObjVal/len(df_seattle)*100)
    else:
        coverage_values.append(0)  # If no optimal solution found, store 0

# Plot the sensitivity analysis results
plt.plot(threshold_range, coverage_values)
plt.xlabel('Distances Threshold')
plt.ylabel('Percentage of Vehicles Covered')
plt.title('Sensitivity Analysis: Distance Threshold vs. Vehicles Covered')
plt.grid(True)
plt.show()

# %% [markdown]
# ### VI. Model Validation & Evaluation

# %% [markdown]
# For this part, we want to compare our result with the allocation of EV charging stations currently in Seattle. We will get the data by requesting the API url with our own developer API key and the queried parameters related to electric vehicle stations.
#
# The data that we collected from energy.gov has been filtered to suit our mapping objectives. Moreover, our focus was on extracting data pertaining to publicly accessible stations offering Level 2 EV charging services.

# %%
# real location dataframe
df_real = pd.read_csv('./electric_stations.csv')
df_real.head()
# Out:
#                                         Station Name     City State    ZIP  \
# 0  Seattle-Tacoma International Airport - General...  Seattle    WA  98188
# 1                           Caplan's Rainbow Parking  Seattle    WA  98104
# 2                  City of Seattle - Central Library  Seattle    WA  98104
# 3                   City of Seattle - Seattle Center  Seattle    WA  98109
# 4                     KING COUNTY DES KSC STATION #1  Seattle    WA  98104
#
#   Status Code Expected Date Owner Type Code Geocode Status   Latitude  \
# 0           E           NaN               P          200-8  47.443377
# 1           T    2022-12-31               P          200-8  47.604115
# 2           E           NaN              LG          200-9  47.606684
# 3           E           NaN              LG          200-8  47.622085
# 4           E           NaN             NaN            GPS  47.598663
#
#     Longitude   Facility Type Restricted Access
# ...

# %%
# Number of stations based on ZIP code from our result
res_location = result_table2.groupby('Postal Code').size().reset_index(name = 'Result')
#res_location["Postal Code"] = '98' + res_location['Postal Code']
res_location = res_location.rename(columns={'Postal Code': 'ZIP'})
res_location["ZIP"] = res_location['ZIP'].astype(str)

# Number of stations based on ZIP code from actual
stations_count = df_real.groupby('ZIP').size().reset_index(name='Actual Location')
stations_count["ZIP"] = stations_count['ZIP'].astype(str)

# combine two df
merged_data = pd.merge(res_location, stations_count, on = "ZIP", how="outer")

# %%
real_charging_stations = {}

for idx, row in df_real.iterrows():
    name = row['Station Name']
    lat = row['Latitude']
    lon = row['Longitude']
    real_charging_stations[name] = (lat, lon)

#Plot the map for real location of charging station
real_map = folium.Map(location=[47.6062, -122.3321], zoom_start=11)
for key, value in real_charging_stations.items():
    folium.Marker(location=value,
                    popup=key,
                    icon=folium.Icon(icon = 'charging-station', color='darkred', prefix='fa')).add_to(real_map)

real_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Define maximum and minimum longitude and latitude ranges
min_lon, max_lon = -122.45, -122.25  
min_lat, max_lat = 47.55, 47.75  

# Define grid size
grid_size = 10

# Define chosen grid locations (assuming 'result' contains grid indices)
chosen = {}
for i in result2:
    chosen[i] = candidate_grid_locations[i]

# Function to map grid location to longitude and latitude
def grid_to_map(lon_idx, lat_idx):
    lon = min_lon + (lon_idx / grid_size) * (max_lon - min_lon)
    lat = min_lat + (lat_idx / grid_size) * (max_lat - min_lat)
    return lat, lon  # Swap lat and lon to store pairs of latitude and longitude

# Convert grid locations to real coordinates
real_locations = {idx: grid_to_map(lon, lat) for idx, (lon, lat) in chosen.items()}

# %%
#Plot the map for model 1
map_mod_1 = folium.Map(location=[47.6062, -122.3321], zoom_start=11)
for key, value in grid.items():
    folium.Marker(location=value,
                    popup=(int(key), n[key]),
                    icon=folium.Icon(icon = 'car', color='blue', prefix='fa')).add_to(map_mod_1)
for key, value in real_locations.items():
    folium.Marker(location=value,
                    popup=key,
                    icon=folium.Icon(icon = 'charging-station', color='red', prefix='fa')).add_to(map_mod_1)

map_mod_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# After comparing our result with the current map of charging stations in Seattle, we found a remarkable similarity between the two maps. However, our result suggests that more charging station should be opened and expanded in the following locations: Shoreline, Mountlake Terrace, Magnolia, Burien, White Center, and Fairwood. In addition, regarding the central parts of Seattle, the number of charging locations should be reduced.

# %% [markdown]
# ### VII. Limitations & Future Studies
#
# While this project aims to identify potential locations for charging stations based on ZIP code data, it has several limitations that should be acknowledged. Firstly, since we use ZIP codes to represent the location of the EVs' users, the selection of candidate charging stations will not be optimized. Additionally, this approach may overlook important considerations, such as land ownership, existing infrastructure, or consumer behaviors. Indeed, there may be locations that are not allowed for station construction or lack of electricity supply. Moreover, our model is based on the assumption that there is a specific supply for each charging station and the regulations in the number of stations can be constructed. In real-world scenarios, the supply of each station could vary and the limitations of station installation are different. Lastly, we have not considered factors such as construction or environmental costs that could potentially influence the selection of the charging station locations.
#
# For future studies, there are several avenues for further exploration and refinement of the methodology used in this project to identify charging station locations. Firstly, we want to incorporate data sources related to land ownership, charginging station construction costs, and real-time tracffic data to get a more comprehensive understanding of charging demand and selections within different geographic areas. In addition, instead of minimizing the total charging stations or maximizing coverage, we want to see how our result changes when the objective is to minimize the total cost (which includes construction and environmental costs). By addressing these considerations and leveraging advanced analytical approaches, future studies have the potential to inform more effective and equitable strategies for expanding electric vehicle charging infrastructure to support the transition to sustainable transportation systems.

# %% [markdown]
# ### VIII. Conclusion

# %% [markdown]
# ### Reference
# Washington State Department of Licensing - Electric Vehicle Population Data. Retrieved from: https://catalog.data.gov/dataset/electric-vehicle-population-data
#
# Alternative Fuels Data Center (AFDC) - Electric Vehicle Charging Station Locator. Retrieved from: https://afdc.energy.gov/fuels/electricity-locations#/find/nearest?fuel=ELEC
#
# King County Metro Zero-Emission Fleet. Retrieved from: https://www.kingcountymetrozefleet.com/?lng=en
#
# King County Sustainable Purchasing Guide for Vehicles. Retrieved from: https://kingcounty.gov/en/legacy/depts/finance-business-operations/procurement/for-government/environmental-purchasing/purchasing_guide/vehicles
