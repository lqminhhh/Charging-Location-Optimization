# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET
from io import StringIO

# Define the URL
url = "https://developer.nrel.gov/api/alt-fuel-stations/v1.csv"

# Define query parameters
query_params = {
    "api_key": "9tTOLG97gY6odZamjcPb1ljjFjNbDjVoeaR7h3yQ",
    "state": "WA",
    "fuel_type" : "ELEC",
    'ev_charging_level': '2'
}

# Make the GET request
response = requests.get(url, params=query_params)

# Check if the request was successful
# if response.status_code == 200:
#     # Print the response content
#     print(response.text)
# else:
#     print("Failed to retrieve data. Status code:", response.status_code)
# Out:
# /Users/minhle/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
df = pd.read_csv(StringIO(response.text))
df
# Out:
#      Fuel Type Code                                       Station Name  \
# 0              ELEC                  City of Lacey - City Hall Parking
# 1              ELEC  Seattle-Tacoma International Airport - General...
# 2              ELEC                                        Avista Corp
# 3              ELEC                                Steam Plant Parking
# 4              ELEC                             BELLEVUE BELLEVUE CH 1
# ...             ...                                                ...
# 2184           ELEC                                 Adams - NW 57th St
# 2185           ELEC                            Fremont - Whitman Ave N
# 2186           ELEC                          Eastlake - Fairview Ave E
# 2187           ELEC                            Riverview - 17th Ave SW
# 2188           ELEC                              Pasco Fire Station 85
#
#            Street Address                     Intersection Directions  \
# 0          420 College St       At 3rd Ave SE, next to police station
# 1     17801 Pacific Hwy S  5th floor parking garage; rows D, G, and I
# 2      1411 E Mission Ave                                         NaN
# 3           130 S Post St                                         NaN
# 4        450 110th Ave NE                                         NaN
# ...                   ...                                         ...
# 2184      1722 NW 57th St                                         NaN
# 2185   3930 Whitman Ave N                                         NaN
# 2186  1936 Fairview Ave E                                         NaN
# 2187     7021 17th Ave SW                                         NaN
# 2188        3624 Road 100                                         NaN
#
#           City State    ZIP  Plus4 Station Phone Status Code  ...  \
# 0        Lacey    WA  98503    NaN  360-491-3214           E  ...
# 1      Seattle    WA  98188    NaN  206-787-5388           E  ...
# 2      Spokane    WA  99252    NaN  509-489-0500           E  ...
# 3      Spokane    WA  99201    NaN  800-227-9187           E  ...
# 4     Bellevue    WA  98004    NaN  888-758-4389           E  ...
# ...        ...   ...    ...    ...           ...         ...  ...
# 2184   Seattle    WA  98107    NaN  855-900-7584           E  ...
# 2185   Seattle    WA  98103    NaN  855-900-7584           E  ...
# 2186   Seattle    WA  98102    NaN  855-900-7584           E  ...
# 2187   Seattle    WA  98106    NaN  855-900-7584           E  ...
# 2188     Pasco    WA  99301    NaN  888-998-2546           E  ...
#
#      Restricted Access RD Blends RD Blends (French) RD Blended with Biodiesel  \
# 0                False       NaN                NaN                       NaN
# 1                False       NaN                NaN                       NaN
# 2                False       NaN                NaN                       NaN
# 3                False       NaN                NaN                       NaN
# 4                  NaN       NaN                NaN                       NaN
# ...                ...       ...                ...                       ...
# 2184               NaN       NaN                NaN                       NaN
# 2185               NaN       NaN                NaN                       NaN
# 2186               NaN       NaN                NaN                       NaN
# 2187               NaN       NaN                NaN                       NaN
# 2188               NaN       NaN                NaN                       NaN
#
#       RD Maximum Biodiesel Level  NPS Unit Name  \
# 0                            NaN            NaN
# 1                            NaN            NaN
# 2                            NaN            NaN
# 3                            NaN            NaN
# 4                            NaN            NaN
# ...                          ...            ...
# 2184                         NaN            NaN
# 2185                         NaN            NaN
# 2186                         NaN            NaN
# 2187                         NaN            NaN
# 2188                         NaN            NaN
#
#       CNG Station Sells Renewable Natural Gas  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 2184                                      NaN
# 2185                                      NaN
# 2186                                      NaN
# 2187                                      NaN
# 2188                                      NaN
#
#       LNG Station Sells Renewable Natural Gas  Maximum Vehicle Class  \
# 0                                         NaN                     LD
# 1                                         NaN                     LD
# 2                                         NaN                     LD
# 3                                         NaN                     LD
# 4                                         NaN                    NaN
# ...                                       ...                    ...
# 2184                                      NaN                    NaN
# 2185                                      NaN                    NaN
# 2186                                      NaN                    NaN
# 2187                                      NaN                    NaN
# 2188                                      NaN                    NaN
#
#       EV Workplace Charging
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ...                     ...
# 2184                  False
# 2185                  False
# 2186                  False
# 2187                  False
# 2188                  False
#
# [2189 rows x 74 columns]

# %%
df.to_csv('electric_stations.csv', index=False)

# %%
df[df.City == "Seattle"].columns
# Out:
# Index(['Fuel Type Code', 'Station Name', 'Street Address',
#        'Intersection Directions', 'City', 'State', 'ZIP', 'Plus4',
#        'Station Phone', 'Status Code', 'Expected Date',
#        'Groups With Access Code', 'Access Days Time', 'Cards Accepted',
#        'BD Blends', 'NG Fill Type Code', 'NG PSI', 'EV Level1 EVSE Num',
#        'EV Level2 EVSE Num', 'EV DC Fast Count', 'EV Other Info', 'EV Network',
#        'EV Network Web', 'Geocode Status', 'Latitude', 'Longitude',
#        'Date Last Confirmed', 'ID', 'Updated At', 'Owner Type Code',
#        'Federal Agency ID', 'Federal Agency Name', 'Open Date',
#        'Hydrogen Status Link', 'NG Vehicle Class', 'LPG Primary',
#        'E85 Blender Pump', 'EV Connector Types', 'Country',
#        'Intersection Directions (French)', 'Access Days Time (French)',
#        'BD Blends (French)', 'Groups With Access Code (French)',
#        'Hydrogen Is Retail', 'Access Code', 'Access Detail Code',
#        'Federal Agency Code', 'Facility Type', 'CNG Dispenser Num',
#        'CNG On-Site Renewable Source', 'CNG Total Compression Capacity',
#        'CNG Storage Capacity', 'LNG On-Site Renewable Source',
#        'E85 Other Ethanol Blends', 'EV Pricing', 'EV Pricing (French)',
#        'LPG Nozzle Types', 'Hydrogen Pressures', 'Hydrogen Standards',
#        'CNG Fill Type Code', 'CNG PSI', 'CNG Vehicle Class',
#        'LNG Vehicle Class', 'EV On-Site Renewable Source', 'Restricted Access',
#        'RD Blends', 'RD Blends (French)', 'RD Blended with Biodiesel',
#        'RD Maximum Biodiesel Level', 'NPS Unit Name',
#        'CNG Station Sells Renewable Natural Gas',
#        'LNG Station Sells Renewable Natural Gas', 'Maximum Vehicle Class',
#        'EV Workplace Charging'],
#       dtype='object')

# %%
import requests
import pandas as pd
# Out:
# /Users/minhle/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
df = pd.read_csv("./electric_stations.csv")
df = df.loc[df["City"] == "Seattle"]
df["ZIP"].unique()
# Out:
# /var/folders/wx/wbgcz7pn4v539b0l83lkt7y40000gn/T/ipykernel_58615/132650460.py:1: DtypeWarning: Columns (7,19,24,30,31,35,36,40,46,63,69,71) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./electric_stations.csv")
# array(['98188', '98104', '98124', '98134', '98109', '98103', '98106',
#        '98108', '98121', '98105', '98065', '98125', '98101', '98154',
#        '98144', '98133', '98107', '98112', '98102', '98115', '98122',
#        '98117', '98195', '98164', '98136', '98191', '98119', '98199',
#        '98126', '98118', '98146', '98178', '98116'], dtype=object)
